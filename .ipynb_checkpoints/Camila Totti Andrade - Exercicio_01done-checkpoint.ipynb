# %% [markdown]
# # Disciplina: Introdução a programação para geocientistas

# %% [markdown]
# ## Exercícios referentes às aulas 4 e 5 - variáveis e operadores

# %%
import numpy as np

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# Crie um algoritmo que imprima a frase abaixo.
#
# `Maria tem 12 anos`
#
# Dicas:
# * Crie variáveis que recebam o nome e a idade;
# * use a função `print`

# %%
nome = 'Maria'
idade = '12 anos'
print (nome, 'tem', idade)
# Out:
# Maria tem 12 anos

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Crie um algoritmo que imprima quantos copos de água você bebeu hoje, como no exemplo abaixo:
#
# `Eu bebi 5 copos de água hoje.`

# %%
copos = int(input())
print ('Eu bebi', copos, 'copos de água hoje')
# Out:
# 5
# Eu bebi 5 copos de água hoje

# %% [markdown]
# ## Exercício 3

# %% [markdown]
# O exemplo abaixo realiza algumas operações com strings, como imprimir texto, números, combinar strings, dividir (*slice*) e acessar elementos.

# %%
x = "Fulano"
print(x)

# Combine números e texto
s = "Meu número da sorte é %d, qual é o seu?" % 7
print(s)

# Método alternativo para combinar números e texto
s = "Meu número da sorte é " + str(7) + ", qual é o seu?"
print(s)

# Imprime caracter por índice
print(x[0])

# Imprime um pedaço de uma string
print(x[0:3])
# Out:
# Fulano
# Meu número da sorte é 7, qual é o seu?
# Meu número da sorte é 7, qual é o seu?
# F
# Ful

# %% [markdown]
# * Usando a função `len()`, retorne o tamanho de s?
# * Tente imprimir a palavra 'sorte' dentro da variável `s` do código anterior.
# * Tente imprimir o dia, mês, ano na forma "Hoje é 01/7/2021".

# %%
print (len(s))
# Out:
# 38

# %%
print (s[14:19])
# Out:
# sorte

# %%
data = 'Hoje é', input ()
print = data
# Out:
# 01/7/2021

# %% [markdown]
# ## Exercício 4

# %% [markdown]
# Dado dois números, retorne o produto entre os dois.
#
# Número 1 = 34
#
# Número 2 = 67

# %%
n1 = 34
n2 = 67
n1 * n2
# Out:
# 2278

# %% [markdown]
# ## Exercício 5

# %% [markdown]
# Dada a imagem abaixo, calcule a distância ($d_{AB}$) entre os pontos A e B dadas as coordenadas a seguir:
#
# - x1 = 2
# - y1 = 2
# - x2 = 6
# - y2 = 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x1 = 2
y1 = 2
x2 = 6
y2 = 9
np.sqrt (((x2 - x1)**2) + ((y2 - y1)**2))
# Out:
# 8.06225774829855

# %% [markdown]
# ## Exercício 6

# %% [markdown]
# Dada a lista de números abaixo, retorne:
#
# lista: 3, 6, 7, 23, 89, 100
#
# a) o maior número
# b) o menor número

# %%
max (3,6,7,23,89,100)
# Out:
# 100

# %%
min (3,6,7,23,89,100)
# Out:
# 3

# %% [markdown]
# Aplique os seguinte operadores relacionais e retorne o resultado (`True` ou `False`)
#
# `89 < 7`

# %%
89 < 7
# Out:
# False

# %% [markdown]
# `100 > 89`

# %%
100 > 89
# Out:
# True

# %% [markdown]
# `23 = 7`

# %%
23 == 7
# Out:
# False

# %% [markdown]
# `3 != 89`

# %%
3 != 89
# Out:
# True

# %% [markdown]
# ## Exercício 7

# %% [markdown]
# Dados,
#
# - x = 10
# - y = -2
# - z = 5
#
# Retorne o resultado dos seguintes operadores lógicos

# %% [markdown]
# w = x * y < z / x or x / y > z * x

# %%
x = 10
y = -2
z =  5

# %%
w = x * y < z /x or x / y > z*x
w
# Out:
# True

# %% [markdown]
# w =  x / y > z * x and z * y < x

# %%
w = x/y > z*x and z*y < x
w
# Out:
# False

# %% [markdown]
# ## Exercício 8

# %% [markdown]
# Dada a expressão
#
# `x = 25 + 15`
#
# Use os operadores de atribuição para retornar:
#
# `x = x + 13`
# `x = x - 8`
# `x = x * 2`
# `x = x / 4`
# `x = x // 2`
# `x = x % 3`
# `x = x ** 3`
#
# Qual o resultado final da variável x?

# %%
x = 25 + 15
x
# Out:
# 40

# %%
x = x + 13

# %%
x = x - 8

# %%
x = x * 2

# %%
x = x /4

# %%
x = x // 2

# %%
x = x % 3

# %%
x = x ** 3

# %%
x
# Out:
# 8.0

# %% [markdown]
# ## Exercício 9

# %% [markdown]
# A intensidade $I$ de um terremoto, medida na escala Richter, é um número que varia de $I=0$ até $I=8,9$ para o maior terremoto conhecido. $I$ é dado pela fórmula
#
# $I = \frac{2}{3}log10(\frac{E}{E_0})$ ,
#
# em que $E$ é a energia liberada pelo terremoto em quilowatt-hora e $E_0=7×10^{−3}$ kwh.
#
# * Qual a intensidade de um terremoto com energia $7 x 10^6$ kWh? Use a função do numpy `np.log10()`

# %%
E = 7 * (10 ** 6)
E0 = 7 * (10 ** -3)
I = 2/3 * (np.log10(E/E0))
print (I, 'kwh')
# Out:
# 6.0 kwh

# %% [markdown]
# ## Exercício 10

# %% [markdown]
# ### Como localizar um terremoto
#
# As velocidades das ondas P e S variam dependendo do meio por onde elas se propagam. Essas ondas sofrem refrações e reflexões no interior da Terra e é possível calcular quanto tempo elas levam para chegar a um dado ponto na superfície. As ondas P se propagam com velocidade $V_P = 8$ km/s e as ondas S com $V_S = 4,5$ km/s.

# %% [markdown]
# A Figura mostra o registro (sismograma) de um terremoto de magnitude 7,2 ocorrido em 2011 na fronteira entre Brasil e Peru. Os dados foram obtidos por um sismógrafo localizado na Nicarágua. Os três gráficos mostram o deslocamento causado pelo tremor nas direções vertical, norte-sul e leste-oeste. Podemos notar que dois tipos de onda chegam ao sismógrafo: primeiro vêm as ondas P, de pequena amplitude e alta frequência, e em seguida surgem as ondas S, com amplitude maior e frequência menor. Os instantes de chegada dessas ondas estão indicados nos gráficos.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Figura 1: Terremoto de magnitude 7,2 ocorrido em agosto de 2011 na fronteira Brasil-Peru, registrado por um sismógrafo na Nicarágua.

# %% [markdown]
# O tempo que as ondas P levam para chegar ao sismógrafo é
#
# TP = D / VP,
#
# as ondas S chegam em
#
# TS = D / VS.
#
# A diferença entre os tempos de chegada das duas ondas é o intervalo entre as duas linhas verticais traçadas, dado por ∆T = TS − TP.
#
# E a distância fica:
#
# $$
# D = \frac{V_PV_S}{V_P - V_S} \Delta T
# $$

# %% [markdown]
# Usando as informações obtidas na figura acima, calcule a distância entre o epicentro do terremoto e a estação sísmica. Atribua os valores de tempo e velocidade a variáveis.

# %% [markdown]
# Referência: https://www.if.ufrj.br/~carlos/artigos/SciAm2012_ondas_terremotos.pdf

# %%
VP = 8
VS = 4.5
TP = 120 
TS = 360
TT = TS - TP

D = ((VP * VS) / (VP - VS) ) * TT
print (D, 'km')
# Out:
# 2468.571428571429 km
